# %%
import os
from sqlalchemy import create_engine

# %%
host = "localhost"
database = "Parking"
user = "postgres"
password = ""

# %%
connection_string = f"postgresql://{user}:{password}@{host}/{database}"

# %%
engine = create_engine(connection_string)

# %%
from sqlalchemy import inspect

# %%
insp = inspect(engine)
insp.get_table_names()
# Out:
# ['spatial_ref_sys',
#  'commercial',
#  'Operation',
#  'Residential',
#  'Restaurants',
#  'Population',
#  'Parking_G',
#  'Supermarket_point',
#  'Operations',
#  'Parking',
#  'Data',
#  'Parking_dummy',
#  'Bank_final',
#  'Parking_operation',
#  'Parking_update',
#  'Operations_1',
#  'Data_1',
#  'doc',
#  'Data_2',
#  'dummy',
#  'Export',
#  'Join_Output_2',
#  'Parking_16',
#  'atm',
#  'Lazy',
#  'Join_Output_8',
#  'Join_Output_4',
#  'Join_Output_10',
#  'cafe']

# %%
import pandas as pd

# %%
sql = 'SELECT * FROM public."Join_Output_4"'

# %%
df = pd.read_sql_query(sql, con=engine)

# %%
df = df.dropna()
df
# Out:
#               id                                               geom    fid_1  \
# 0        4427776  0101000020E610000041C1ADB71CC42A401674F50B0647...        0
# 1        4429370  0101000020E610000041C1ADB71CC42A401674F50B0647...        1
# 2        4429872  0101000020E610000041C1ADB71CC42A401674F50B0647...        2
# 3        4429993  0101000020E610000041C1ADB71CC42A401674F50B0647...        3
# 4        4430384  0101000020E610000041C1ADB71CC42A401674F50B0647...        4
# ...          ...                                                ...      ...
# 4455354  1870236  0101000020E6100000D97F5E51D5E32A408BE61A8B6D41...  4455354
# 4455355  1870309  0101000020E6100000D97F5E51D5E32A408BE61A8B6D41...  4455355
# 4455356  1870329  0101000020E6100000D97F5E51D5E32A408BE61A8B6D41...  4455356
# 4455357  1870347  0101000020E6100000D97F5E51D5E32A408BE61A8B6D41...  4455357
# 4455358  1870379  0101000020E6100000D97F5E51D5E32A408BE61A8B6D41...  4455358
#
# ...

# %%
sql = 'SELECT * FROM public."Join_Output_2"'

# %%
df1 = pd.read_sql_query(sql, con=engine)

# %%
df1 = df1.dropna()
df1
# Out:
#       id                                               geom  fid_1  \
# 0      1  0101000020E6100000713D0AD7A3102B40D42B6519E230...    600
# 1      2  0101000020E6100000713D0AD7A3102B40D42B6519E230...    601
# 2      3  0101000020E6100000713D0AD7A3102B40D42B6519E230...    602
# 3      4  0101000020E6100000713D0AD7A3102B40D42B6519E230...    603
# 4      5  0101000020E6100000713D0AD7A3102B40D42B6519E230...    604
# ..   ...                                                ...    ...
# 715  716  0101000020E6100000A7E8482EFF012B40295C8FC2F550...    235
# 716  717  0101000020E6100000A7E8482EFF012B40295C8FC2F550...    236
# 717  718  0101000020E6100000A7E8482EFF012B40295C8FC2F550...    237
# 718  719  0101000020E6100000A7E8482EFF012B40295C8FC2F550...    238
# 719  720  0101000020E6100000A7E8482EFF012B40295C8FC2F550...    239
#
#          station                   name  latitude  longitude  elevation  \
# 0    GME00127930  BERLIN SCHONEFELD, GM   52.3819    13.5325       46.0
# ...

# %%
merge_df = pd.merge(df , df1,  how='inner', left_on=['arrival','input_fid'], right_on = ['date','input_fid'])

# %%
merge_df
# Out:
#             id_x                                             geom_x  fid_1_x  \
# 0        4427776  0101000020E610000041C1ADB71CC42A401674F50B0647...        0
# 1        4427393  0101000020E610000041C1ADB71CC42A401674F50B0647...      403
# 2        4427793  0101000020E610000052B3F2903AC42A401003D3290747...      575
# 3        4427409  0101000020E6100000925E350724C42A40FF04B6F00947...     1210
# 4        4427423  0101000020E6100000925E350724C42A40FF04B6F00947...     1211
# ...          ...                                                ...      ...
# 4455288  2015790  0101000020E6100000BA94EC23DBED2A404565717CE245...  2453728
# 4455289  2015783  0101000020E61000000A35D708B2ED2A40BCD3324EE045...  2453871
# 4455290  2015799  0101000020E6100000F826EAC39FED2A40D4041756DF45...  2457608
# 4455291  2015793  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2457989
# 4455292  2015787  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2458030
#
# ...

# %%
data_parking_lot_id = merge_df.groupby(['parking_lo','arrival'])['occupancy'].sum().reset_index()

# %%
data_parking_lot_id
# Out:
#        parking_lo     arrival  occupancy
# 0              79  2021-01-01        142
# 1              79  2021-01-02      23010
# 2              79  2021-01-03        269
# 3              79  2021-01-04      28880
# 4              79  2021-01-05      22294
# ...           ...         ...        ...
# 10258        2705  2021-04-26      13853
# 10259        2705  2021-04-27      12099
# 10260        2705  2021-04-28      10593
# 10261        2705  2021-04-29      16614
# 10262        2705  2021-04-30      20272
#
# [10263 rows x 3 columns]

# %%
park_1123 = data_parking_lot_id[data_parking_lot_id['parking_lo']==1123]
park_1123 = park_1123.sort_values('arrival')

# %%
park_1123
# Out:
#       parking_lo     arrival  occupancy
# 7061        1123  2021-01-01         17
# 7062        1123  2021-01-02       7258
# 7063        1123  2021-01-03        186
# 7064        1123  2021-01-04      12704
# 7065        1123  2021-01-05       9497
# ...          ...         ...        ...
# 7176        1123  2021-04-26       9016
# 7177        1123  2021-04-27       7669
# 7178        1123  2021-04-28       7087
# 7179        1123  2021-04-29       8808
# 7180        1123  2021-04-30      10260
#
# [120 rows x 3 columns]

# %%
df = merge_df

# %%
df
# Out:
#             id_x                                             geom_x  fid_1_x  \
# 0        4427776  0101000020E610000041C1ADB71CC42A401674F50B0647...        0
# 1        4427393  0101000020E610000041C1ADB71CC42A401674F50B0647...      403
# 2        4427793  0101000020E610000052B3F2903AC42A401003D3290747...      575
# 3        4427409  0101000020E6100000925E350724C42A40FF04B6F00947...     1210
# 4        4427423  0101000020E6100000925E350724C42A40FF04B6F00947...     1211
# ...          ...                                                ...      ...
# 4455288  2015790  0101000020E6100000BA94EC23DBED2A404565717CE245...  2453728
# 4455289  2015783  0101000020E61000000A35D708B2ED2A40BCD3324EE045...  2453871
# 4455290  2015799  0101000020E6100000F826EAC39FED2A40D4041756DF45...  2457608
# 4455291  2015793  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2457989
# 4455292  2015787  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2458030
#
# ...

# %%
df_filtered = df[df['occupancy'] > 7]

# %%
df_filtered
# Out:
#             id_x                                             geom_x  fid_1_x  \
# 0        4427776  0101000020E610000041C1ADB71CC42A401674F50B0647...        0
# 1        4427393  0101000020E610000041C1ADB71CC42A401674F50B0647...      403
# 2        4427793  0101000020E610000052B3F2903AC42A401003D3290747...      575
# 3        4427409  0101000020E6100000925E350724C42A40FF04B6F00947...     1210
# 4        4427423  0101000020E6100000925E350724C42A40FF04B6F00947...     1211
# ...          ...                                                ...      ...
# 4455287  2015788  0101000020E6100000BA94EC23DBED2A404565717CE245...  2453727
# 4455288  2015790  0101000020E6100000BA94EC23DBED2A404565717CE245...  2453728
# 4455290  2015799  0101000020E6100000F826EAC39FED2A40D4041756DF45...  2457608
# 4455291  2015793  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2457989
# 4455292  2015787  0101000020E6100000C31B6346E4ED2A40B94C7FF8E245...  2458030
#
# ...

# %%
df = df_filtered

# %%
df.drop(['geom_x', 'fid_1_x', 'objectid', 'shape_leng', 'id_y', 'geom_y', 'fid_1_y', 'station', 'name', 'latitude_y', 'longitude_y', 'elevation'], axis = 1)
# Out:
#             id_x  parking_lo  parking_sp  latitude_x  longitude_x     arrival  \
# 0        4427776         315       16285   52.554872    13.383032  2021-03-15
# 1        4427393         315       16285   52.554872    13.383032  2021-03-15
# 2        4427793         315       16256   52.554906    13.383259  2021-03-15
# 3        4427409         315       16251   52.554991    13.383087  2021-03-15
# 4        4427423         315       16251   52.554991    13.383087  2021-03-15
# ...          ...         ...         ...         ...          ...         ...
# 4455287  2015788         940       39316   52.545974    13.464563  2021-01-31
# 4455288  2015790         940       39316   52.545974    13.464563  2021-01-31
# 4455290  2015799         940       39362   52.545878    13.464110  2021-01-31
# 4455291  2015793         940       39361   52.545989    13.464632  2021-01-31
# 4455292  2015787         940       39361   52.545989    13.464632  2021-01-31
#
# ...

# %%
df1 = df.drop(['geom_x', 'fid_1_x', 'objectid', 'shape_leng', 'id_y', 'geom_y', 'fid_1_y', 'station', 'name', 'latitude_y', 'longitude_y', 'elevation', 'latitude_x', 'longitude_x', 'shape_area', 'input_fid', 'date'], axis = 1)

# %%
df1.to_csv('C:\Master thesis\Parking_prc.csv', sep=',')

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
list(df.columns)
# Out:
# ['id_x',
#  'geom_x',
#  'fid_1_x',
#  'parking_lo',
#  'parking_sp',
#  'latitude_x',
#  'longitude_x',
#  'arrival',
#  'departure',
#  'res_percen',
#  'com_percen',
#  'population',
#  'restaurant',
#  'occupancy',
#  'amenity',
#  'objectid',
#  'shape_leng',
#  'shape_area',
#  'input_fid',
#  'id_y',
#  'geom_y',
#  'fid_1_y',
#  'station',
#  'name',
#  'latitude_y',
#  'longitude_y',
#  'elevation',
#  'date',
#  'prcp',
#  'snwd',
#  'tmax',
#  'tmin']

# %%
from sklearn.ensemble import RandomForestRegressor
X = df[['restaurant','population','res_percen','com_percen','amenity','prcp','snwd']]
y=df['occupancy']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
regressor = RandomForestRegressor(n_estimators = 100, random_state =0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 23.15707449, 503.50218855,  27.97372041, ...,  14.12457686,
#         18.48540721,  22.9526355 ])

# %%
new = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
new
# Out:
#          Real Values  Predicted Values
# 2626405           15         23.157074
# 4077977           23        503.502189
# 4178307           17         27.973720
# 3761805            9         11.683171
# 134582            29         21.830490
# ...              ...               ...
# 1147936           16         14.609965
# 3518548           20         23.503989
# 3923312            1         14.124577
# 3250393            9         18.485407
# 3828363           13         22.952636
#
# [1336588 rows x 2 columns]

# %%
from sklearn import metrics
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
explained_variance_score(y_test, y_pred)
# Out:
# Mean Absolute Error: 26.414861610542385
# Mean Squared Error: 117233.09449177838
# Root Mean Squared Error: 342.3931869821279
# -0.06892883016177631

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
from sklearn.inspection import permutation_importance
importances = regressor.feature_importances_
sorted_indices = np.argsort(importances)[::-1]

plt.title('feature importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show()
