# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_excel("Task.xls", sheet_name = 0)
df[:2]
# Out:
#   observation_date  PCU4831114831115
# 0       1988-06-01             100.0
# 1       1988-07-01             104.6

# %%
df.columns = ["Date", "Values"]
df[:10]
# Out:
#         Date  Values
# 0 1988-06-01   100.0
# 1 1988-07-01   104.6
# 2 1988-08-01   102.6
# 3 1988-09-01   107.2
# 4 1988-10-01   102.1
# 5 1988-11-01   102.5
# 6 1988-12-01   106.1
# 7 1989-01-01   105.9
# 8 1989-02-01   106.1
# 9 1989-03-01   107.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    395 non-null    datetime64[ns]
#  1   Values  395 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 KB

# %%
df.describe()
# Out:
#            Values
# count  395.000000
# mean   200.414430
# std     70.132089
# min    100.000000
# 25%    116.550000
# 50%    230.100000
# 75%    258.100000
# max    327.700000

# %%
df["Derivative"] = df["Values"].diff()
df[:2]
# Out:
#         Date  Values  Derivative
# 0 1988-06-01   100.0         NaN
# 1 1988-07-01   104.6         4.6

# %% [markdown]
# ### Error Bars for all Dates

# %%
plt.figure(figsize = (18, 7))
x = df["Date"]
dy = df["Derivative"]
y = df["Values"]

plt.errorbar(x, y, yerr=dy, fmt='o',ecolor = "red", color='blue', capsize = 10)
plt.title("Error Bars by Producer Price Index for All Dates", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %%
plt.figure(figsize = (18, 7))
plt.plot(x, y, color = "blue")
plt.title("Line Plot by Producer Price Index for All Dates", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %% [markdown]
# ### Error bars of Dates 1/12/2019 - 1/4/2021

# %%
mask_a = (df["Date"] >= "2019-12-01") & (df["Date"] <= "2021-04-01")
df_a = df.loc[mask_a]
df_a[:5]
# Out:
#           Date  Values  Derivative
# 378 2019-12-01   327.5         3.8
# 379 2020-01-01   327.7         0.2
# 380 2020-02-01   310.7       -17.0
# 381 2020-03-01   308.6        -2.1
# 382 2020-04-01   293.1       -15.5

# %%
plt.figure(figsize = (18, 7))
x = df_a["Date"]
dy = df_a["Derivative"]
y = df_a["Values"]

plt.errorbar(x, y, yerr=dy, fmt='o',ecolor = "red", color='blue', capsize = 10)
plt.title("Error Bars by Producer Price Index for  1/12/2019 - 1/4/2021", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %%
plt.figure(figsize = (18, 7))
plt.plot(x, y, color = "blue")
plt.title("Line Plot by Producer Price Index for 1/12/2019 - 1/4/2021", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %% [markdown]
# ### Error Bars of Dates 1/01/2002 - 1/01/2012

# %%
mask_b = (df["Date"] >= "2002-01-01") & (df["Date"] <= "2012-01-01")
df_b = df.loc[mask_b]
df_b[:5]
# Out:
#           Date  Values  Derivative
# 163 2002-01-01   174.0        -0.9
# 164 2002-02-01   173.7        -0.3
# 165 2002-03-01   172.9        -0.8
# 166 2002-04-01   170.7        -2.2
# 167 2002-05-01   180.1         9.4

# %%
plt.figure(figsize = (18, 7))
x = df_b["Date"]
dy = df_b["Derivative"]
y = df_b["Values"]

plt.errorbar(x, y, yerr=dy, fmt='o',ecolor = "red", color='blue', capsize = 10)
plt.title("Error Bars by Producer Price Index for  1/01/2002 - 1/01/2012", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %%
plt.figure(figsize = (18, 7))
plt.plot(x, y, color = "blue")
plt.title("Line Plot by Producer Price Index for 01/01/2002 - 01/01/2012", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()

# %% [markdown]
# ### Error Line Graph of Task 2 and 3

# %%
mask_c = (df["Date"] >= "2002-01-01") & (df["Date"] <= "2012-01-01") | (df["Date"] >= "2019-12-01") & (df["Date"] <= "2021-04-01")
df_c = df.loc[mask_c]
df_c[:5]
# Out:
#           Date  Values  Derivative
# 163 2002-01-01   174.0        -0.9
# 164 2002-02-01   173.7        -0.3
# 165 2002-03-01   172.9        -0.8
# 166 2002-04-01   170.7        -2.2
# 167 2002-05-01   180.1         9.4

# %%
plt.figure(figsize = (18, 7))
x = df_c["Date"]
dy = df_c["Derivative"]
y = df_c["Values"]

plt.errorbar(x, y, yerr=dy, fmt='o',ecolor = "red", color='blue', capsize = 5);
plt.plot(x, y, color = "orange")
plt.title("Error Line Graph by Producer Price Index for  1/01/2002 - 1/01/2012", size = 15)
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.show()
